# %% [markdown]
# <a href="https://www.kaggle.com/code/anthonyortiz2024/global-hack-week-anthony-ortiz?scriptVersionId=158357931" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# This challenge is making the code write to say “hello, world!”

# %%
print("Hello World!")
# Out:
# Hello World!
