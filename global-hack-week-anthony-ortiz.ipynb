# %% [markdown]
# <a href="https://www.kaggle.com/code/anthonyortiz2024/global-hack-week-anthony-ortiz?scriptVersionId=158539510" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %% [markdown]
# This challenge is making the code write to say “hello, world!”

# %%
print("Hello World!")
# Out:
# Hello World!

# %% [markdown]
# This code simulates write a sorting method

# %%
planets = ['Mercury', 'Venus', 'Earth', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']
planets[:3] = ['Mur', 'Vee', 'Ur']
print(planets)
# That was silly. Let's give them back their old names
planets[:4] = ['Mercury', 'Venus', 'Earth', 'Mars',]
# Out:
# ['Mur', 'Vee', 'Ur', 'Mars', 'Jupiter', 'Saturn', 'Uranus', 'Neptune']

# %% [markdown]
# This code simulates a rock, paper, scissor game!

# %% [markdown]
# This code simulates a random number generator

# %%
# importing "random" for random operations
import random
 
# using random() to generate a random number
# between 0 and 1
print("A random number between 0 and 1 is : ", end="")
print(random.random())
# Out:
# A random number between 0 and 1 is : 0.10368901799793628

# %% [markdown]
# This code simulates a Useless Hack

# %%
People=10
Apples=20
Math= Apples/People
print(Math)
# Out:
# 2.0

# %% [markdown]
# This code simulates finding and using libraries

# %%
from astropy import units as u

import numpy as np

distances= np.array([36,3.2,87.4,549.2])
print("distance array with no units", distances)

distancemeters=distances*u.m  
#variableaddingtounits*u.<unit you want>
print("array w/ units", distancemeters)
# Out:
# distance array with no units [ 36.    3.2  87.4 549.2]
# array w/ units [ 36.    3.2  87.4 549.2] m
